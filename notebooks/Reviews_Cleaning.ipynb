# %%
import numpy as np
import pandas as pd 
from zytholic_project.reviews_data import BaseModelRev

# %%
dfbeer = pd.read_csv("../raw_data/beers_style_renamed.csv")
dftop = pd.read_csv("../raw_data/top_beer_info_style_renamed.csv")
dfbeer2 = pd.read_csv("../raw_data/Beers_Breweries_and_Beer Reviews/beers.csv")

# %%
dfreviews = pd.read_csv("../raw_data/Beers_Breweries_and_Beer Reviews/reviews.csv",chunksize=1000000)

# %%
dfrev = pd.concat([chunk for chunk in dfreviews])

# %%
model = BaseModelRev()

model.get_data()
dfid = model.working_df['id']

dfidlist = dfid.to_list()
# Out:
# /root/.pyenv/versions/lewagon/envs/zytholic_project/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
#dfid = dfid.rename(columns={"id": "beer_id"})
dfrevclean =dfrev[dfrev['beer_id'].isin(dfidlist)]

dfrevclean
# Out:
#          beer_id         username        date  \
# 1         125646          _dirty_  2017-12-21
# 2         125646          CJDUBYA  2017-12-21
# 3         125646  GratefulBeerGuy  2017-12-20
# 4         125646         LukeGude  2017-12-20
# 5         125646          jneff33  2017-12-20
# ...          ...              ...         ...
# 9073093    58482       beerthulhu  2009-08-24
# 9073094    58482        Billolick  2009-08-24
# 9073095    58482           smcolw  2009-08-22
# 9073096    58482    firkinhophead  2009-08-21
# 9073097    58482          CHADMC3  2009-08-21
#
#                                                       text  look  smell  \
# 1                                                           4.50   4.50
# 2                                                           4.75   4.75
# 3           0% 16 oz can. Funny story: As I finally wal...  4.75   4.75
# 4           Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50
# ...

# %%
dfrevclean2 = dfrevclean.drop(columns=['username','date'])
#Reviews_Clean.to_csv(index=False)

# %%
#dfrevclean2.to_csv("reviews_top_beer_withoutuserdate")
