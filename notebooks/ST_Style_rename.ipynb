# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
top_beer_info = pd.read_csv('/Users/ltexp1998/code/ltexp1998/zytholic_project/raw_data/top-beer-information/top_beer_information.csv')

top_beer_info.head(5)
# Out:
#              Name  key    Style  Style Key                         Brewery  \
# 0           Amber  251  Altbier          8             Alaskan Brewing Co.
# 1      Double Bag  252  Altbier          8          Long Trail Brewing Co.
# 2  Long Trail Ale  253  Altbier          8          Long Trail Brewing Co.
# 3    Doppelsticke  254  Altbier          8  Uerige Obergärige Hausbrauerei
# 4          Scurry  255  Altbier          8               Off Color Brewing
#
#                                          Description  ABV  Ave Rating  \
# 0  Notes:Richly malty and long on the palate, wit...  5.3        3.65
# 1  Notes:This malty, full-bodied double alt is al...  7.2        3.90
# 2  Notes:Long Trail Ale is a full-bodied amber al...  5.0        3.58
# 3                                             Notes:  8.5        4.15
# 4  Notes:Just cause it's dark and German doesn't ...  5.3        3.67
#
#    Min IBU  Max IBU  ...  Body  Alcohol  Bitter  Sweet  Sour  Salty  Fruits  \
# 0       25       50  ...    32        9      47     74    33      0      33
# 1       25       50  ...    57       18      33     55    16      0      24
# 2       25       50  ...    37        6      42     43    11      0      10
# 3       25       50  ...    55       31      47    101    18      1      49
# 4       25       50  ...    69       10      63    120    14      0      19
#
#    Hoppy  Spices  Malty
# 0     57       8    111
# 1     35      12     84
# 2     54       4     62
# 3     40      16    119
# 4     36      15    218
#
# [5 rows x 21 columns]

# %%
beers = pd.read_csv('/Users/ltexp1998/code/ltexp1998/zytholic_project/raw_data/Beers_Breweries_and_Beer Reviews/beers.csv')

beers.head(5)
# Out:
#        id                                  name  brewery_id state country  \
# 0  202522                        Olde Cogitator        2199    CA      US
# 1   82352  Konrads Stout Russian Imperial Stout       18604   NaN      NO
# 2  214879                        Scottish Right       44306    IN      US
# 3  320009               MegaMeow Imperial Stout        4378    WA      US
# 4  246438                       Peaches-N-Cream       44617    PA      US
#
#                      style availability   abv                   notes retired
# 0    English Oatmeal Stout     Rotating   7.3  No notes at this time.       f
# 1   Russian Imperial Stout     Rotating  10.4  No notes at this time.       f
# 2             Scottish Ale   Year-round   4.0  No notes at this time.       t
# 3  American Imperial Stout       Winter   8.7    Every time this year       f
# 4       American Cream Ale     Rotating   5.1  No notes at this time.       f

# %%
style_csv = pd.read_csv('/Users/ltexp1998/code/ltexp1998/zytholic_project/notebooks/style_rename.csv')
style_csv.drop(columns='Unnamed: 0', inplace=True)

# %%
style_csv.set_index('Dataset style',inplace = True)
style_csv.drop('Original',0,inplace=True)
# Out:
# /var/folders/07/zjwdx2397n1gh6yj__wpmd980000gn/T/ipykernel_16712/2739813026.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   style_csv.drop('Original',0,inplace=True)

# %%
style_csv.head(5)
# Out:
#                                           Unnamed: 1
# Dataset style
# Altbier                                      Altbier
# American Adjunct Lager      Adjunct Lager - American
# American Amber / Red Ale          Ale Red - American
# American Amber / Red Lager       Lager Red- American
# American Barleywine            Barleywine - American

# %%
style_dict = style_csv.to_dict()

# %%
style_dict = style_dict['Unnamed: 1']
style_dict
# Out:
# {'Altbier': 'Altbier',
#  'American Adjunct Lager': 'Adjunct Lager - American',
#  'American Amber / Red Ale': 'Ale Red - American',
#  'American Amber / Red Lager': 'Lager Red- American',
#  'American Barleywine': 'Barleywine - American',
#  'American Black Ale': 'Ale Black - American',
#  'American Blonde Ale': 'Ale Blonde - American',
#  'American Brett': 'Brett - American',
#  'American Brown Ale': 'Ale Brown - American',
#  'American Brut IPA': 'IPA Brut- American',
#  'American Cream Ale': 'Ale Cream - American',
#  'American Dark Wheat Ale': 'Ale Dark Wheat - American',
#  'American Imperial IPA': 'IPA imperial - American',
#  'American Imperial Pilsner': 'Pilsner Imperial - American',
#  'American Imperial Porter': 'Porter Imperial - American',
#  'American Imperial Red Ale': 'Ale Imperial Red - American',
#  'American Imperial Stout': 'Stout Imperial - American',
#  'American IPA': 'IPA - American',
#  'American Lager': 'Lager - American',
#  'American Light Lager': 'Lager Light - American',
#  'American Malt Liquor': 'Malt Liquor - American',
#  'American Pale Ale (APA)': 'Ale Pale - American',
#  'American Pale Wheat Ale': 'Ale Pale Wheat - American',
#  'American Porter': 'Porter - American',
#  'American Stout': 'Stout - American',
#  'American Strong Ale': 'Ale Strong - American',
#  'American Wheatwine Ale': 'Ale Wheatwine Ale - American',
#  'American Wild Ale': 'Ale Wild - American',
#  'Baltic Porter': 'Porter Baltic',
#  'Barleywine - American': 'Barleywine - American',
#  'Barleywine - English': 'Barleywine - English',
#  'Belgian Blonde Ale': 'Ale Blonde - Belgian',
#  'Belgian Dark Ale': 'Ale Dark - Belgian',
#  'Belgian Dubbel': 'Dubbel - Belgian',
#  'Belgian Faro': 'Faro - Belgian',
#  'Belgian Fruit Lambic': 'Lambic Fruit- Belgian',
#  'Belgian Gueuze': 'Gueuze - Belgian',
#  'Belgian IPA': 'IPA - Belgian',
#  'Belgian Lambic': 'Lambic - Belgian',
#  'Belgian Pale Ale': 'Ale Pale - Belgian',
#  'Belgian Quadrupel (Quad)': 'Quadrupel - Belgian',
#  'Belgian Saison': 'Saison - Belgian',
#  'Belgian Strong Dark Ale': 'Ale Strong Dark - Belgian',
#  'Belgian Strong Pale Ale': 'Ale Strong Pale - Belgian',
#  'Belgian Tripel': 'Tripel - Belgian',
#  'Belgian Witbier': 'Witbier Wheat - Belgian',
#  'Berliner Weisse': 'Weisse - Belgian',
#  'Bière de Champagne / Bière Brut': 'Bière de Champagne / Bière Brut',
#  'Bitter - English': 'Bitter - English',
#  'Bitter - English Extra Special / Strong Bitter (ESB)': 'Bitter Strong - English',
#  'Blonde Ale - American': 'Ale Blonde - American',
#  'Blonde Ale - Belgian': 'Ale Blonde - Belgian',
#  'Bock - Doppelbock': 'Doppelbock',
#  'Bock - Eisbock': 'Eisbock',
#  'Bock - Maibock': 'Maibock',
#  'Bock - Traditional': 'Bock',
#  'Bock - Weizenbock': 'Weizenbock',
#  'Bohemian Pilsener': 'Pilsener Bohemian',
#  'Braggot': 'Braggot',
#  'Brett Beer': 'Brett',
#  'British Barleywine': 'Barleywine - English',
#  'Brown Ale - American': 'Ale Brown - American',
#  'Brown Ale - Belgian Dark': 'Ale Brown - Belgian',
#  'Brown Ale - English': 'Ale Brown - English',
#  'California Common / Steam Beer': 'Steam Beer - American',
#  'Chile Beer': 'Beer - Chilian',
#  'Cream Ale': 'Ale Cream - American',
#  'Dubbel': 'Dubbel - Belgian',
#  'English Bitter': 'Bitter - English',
#  'English Brown Ale': 'Ale Brown - English',
#  'English Dark Mild Ale': 'Ale Dark Mild - English',
#  'English Extra Special / Strong Bitter (ESB)': 'Bitter Strong - English',
#  'English India Pale Ale (IPA)': 'IPA - English',
#  'English Oatmeal Stout': 'Stout Oatmeal - English',
#  'English Old Ale': 'Ale Old - English',
#  'English Pale Ale': 'Ale Pale - English',
#  'English Pale Mild Ale': 'Ale Pale Mild - English',
#  'English Porter': 'Porter - English',
#  'English Stout': 'Stout - English',
#  'English Strong Ale': 'Ale Strong - English',
#  'English Sweet / Milk Stout': 'Stout Milk - English',
#  'European Dark Lager': 'Lagger Dark - European',
#  'European Export / Dortmunder': 'Dortmunder - European',
#  'European Pale Lager': 'Lager Pale - European',
#  'European Strong Lager': 'Lager Strong - European',
#  'Farmhouse Ale - Bière de Garde': 'Bière de Garde - Farmhouse Ale',
#  'Farmhouse Ale - Sahti': 'Sahti - Farmhouse Ale',
#  'Farmhouse Ale - Saison': 'Saison - Farmhouse Ale',
#  'Finnish Sahti': 'Sahti - Finnish',
#  'Flanders Oud Bruin': 'Old Bruin - Flanders',
#  'Flanders Red Ale': 'Ale Red - Flanders',
#  'Foreign / Export Stout': 'Stout - Foreign',
#  'French Bière de Garde': 'Bière de Garde - French',
#  'Fruit and Field Beer': 'Fruit and Field Beer',
#  'German Altbier': 'Altbier - German',
#  'German Bock': 'Bock - German',
#  'German Doppelbock': 'Doppelbock - German',
#  'German Dunkelweizen': 'Dunkelweizen - German',
#  'German Eisbock': 'Eisbock - German',
#  'German Hefeweizen': 'Hefeweizen - German',
#  'German Helles': 'Lager Helles - German',
#  'German Kellerbier / Zwickelbier': 'Lager Kellerbier / Zwickelbier - German',
#  'German Kölsch': 'Klösch - German',
#  'German Kristalweizen': 'Kristalweizen - German',
#  'German Maibock': 'Maibock - German',
#  'German Märzen / Oktoberfest': 'Lager Märzen / Oktoberfest - German',
#  'German Pilsner': 'Pilsner - German',
#  'German Rauchbier': 'Rauchbier - German',
#  'German Roggenbier': 'Roggenbier - German',
#  'German Schwarzbier': 'Schwarzbier - German',
#  'German Weizenbock': 'Weizenbock - German',
#  'Gruit / Ancient Herbed Ale': 'Ale Gruit / Ancient Herbed',
#  'Happoshu': 'Happoshu - Japanese',
#  'Herb and Spice Beer': 'Herb and Spice Beer',
#  'IPA - American': 'IPA - American',
#  'IPA - Belgian': 'IPA - Belgian',
#  'IPA - Black / Cascadian Dark Ale': 'IPA - Black / Cascadian Dark Ale',
#  'IPA - Brut': 'IPA - Brut',
#  'IPA - English': 'IPA - English',
#  'IPA - Imperial': 'IPA - Imperial',
#  'IPA - New England': 'NEIPA',
#  'Irish Dry Stout': 'Stout Dry - Irish',
#  'Irish Red Ale': 'Ale Red - Irish',
#  'Japanese Happoshu': 'Happoshu - Japanese',
#  'Japanese Rice Lager': 'Lager Rice - Japanese',
#  'Kölsch': 'Kölsch',
#  'Kvass': 'Kvass',
#  'Lager - Adjunct': 'Lager - Adjunct',
#  'Lager - American': 'Lager - American',
#  'Lager - American Amber / Red': 'Lager Red Amber - American',
#  'Lager - European / Dortmunder Export': 'Lager - European / Dortmunder Export',
#  'Lager - European Dark': 'Lager Dark - European',
#  'Lager - European Pale': 'Lager Pale - European',
#  'Lager - European Strong': 'Lager Strong - European',
#  'Lager - Helles': 'Lager Helles',
#  'Lager - India Pale Lager (IPL)': 'Lager India Pale',
#  'Lager - Japanese Rice': 'Lager Rice - Japanese',
#  'Lager - Kellerbier / Zwickelbier': 'Lager Kellerbier / Zwickelbier - German',
#  'Lager - Light': 'Lager Light - American',
#  'Lager - Malt Liquor': 'Malt Liquor - American',
#  'Lager - Märzen / Oktoberfest': 'Lager Märzen / Oktoberfest - German',
#  'Lager - Munich Dunkel': 'Lager Munich Dunkel - German',
#  'Lager - Rauchbier': 'Lager Rauchbier - German',
#  'Lager - Schwarzbier': 'Lager Schwarzbier - German',
#  'Lager - Vienna': 'Lager - Vienna',
#  'Lambic - Faro': 'Faro - Belgian',
#  'Lambic - Fruit': 'Lambic Fruit- Belgian',
#  'Lambic - Gueuze': 'Gueuze - Belgian',
#  'Lambic - Traditional': 'Lambic - Belgian',
#  'Leipzig Gose': 'Gose - Leipzig',
#  'Low Alcohol Beer': 'Low Alcohol Beer',
#  'Mild Ale - English Dark': 'Ale Dark Mild - English',
#  'Mild Ale - English Pale': 'Ale Pale - English',
#  'Munich Dunkel Lager': 'Lager Munich Dunkel - German',
#  'New England IPA': 'NEIPA',
#  'Old Ale': 'Ale Old - English',
#  'Pale Ale - American': 'Ale Pale - American',
#  'Pale Ale - Belgian': 'Ale Pale - Belgian',
#  'Pale Ale - English': 'Ale Pale - English',
#  'Pilsner - Bohemian / Czech': 'Pilsener Bohemian - Czech',
#  'Pilsner - German': 'Pilsner - German',
#  'Pilsner - Imperial': 'Pilsner - Imperial',
#  'Porter - American': 'Porter - American',
#  'Porter - Baltic': 'Porter Baltic',
#  'Porter - English': 'Porter - English',
#  'Porter - Imperial': 'Porter Imperial',
#  'Porter - Robust': 'Porter Robust',
#  'Porter - Smoked': 'Porter Smoked',
#  'Pumpkin Beer': 'Pumpkin Beer',
#  'Quadrupel (Quad)': 'Quadrupel - Belgian',
#  'Red Ale - American Amber / Red': 'Ale Red - American',
#  'Red Ale - Imperial': 'Ale Red Imperial',
#  'Red Ale - Irish': 'Ale Red - Irish',
#  'Robust Porter': 'Porter Robust',
#  'Russian Imperial Stout': 'Stout Russian Imperial',
#  'Russian Kvass': 'Kvass - Russian',
#  'Rye Beer': 'Rye Beer',
#  'Rye Beer - Roggenbier': 'Rye Beer - Roggenbier',
#  'Scotch Ale / Wee Heavy': 'Ale - Scotch',
#  'Scottish Ale': 'Ale - Scottish',
#  'Scottish Gruit / Ancient Herbed Ale': 'Ale Gruit - Scottish',
#  'Smoke Beer': 'Smoke Beer',
#  'Smoke Porter': 'Porter Smoked',
#  'Smoked Beer': 'Smoked',
#  'Sour - Berliner Weisse': 'Sour Berliner Weisse - German',
#  'Sour - Flanders Oud Bruin': 'Sour Oud Bruin - Flanders',
#  'Sour - Flanders Red Ale': 'Sour Red Ale - Flanders',
#  'Sour - Gose': 'Sour Gose',
#  'Stout - American': 'Stout - American',
#  'Stout - American Imperial': 'Stout Imperial - American',
#  'Stout - English': 'Stout - English',
#  'Stout - Foreign / Export': 'Stout - Foreign / Export',
#  'Stout - Irish Dry': 'Stout Dry - Irish',
#  'Stout - Oatmeal': 'Stout Oatmeal - English',
#  'Stout - Russian Imperial': 'Stout Russian Imperial',
#  'Stout - Sweet / Milk': 'Stout Milk',
#  'Strong Ale - American': 'Ale Strong - American',
#  'Strong Ale - Belgian Dark': 'Ale Strong Dark - Belgian',
#  'Strong Ale - Belgian Pale': 'Ale Strong Pale - Belgian',
#  'Strong Ale - English': 'Ale Strong - English',
#  'Tripel': 'Tripel - Belgian',
#  'Vienna Lager': 'Lager - Vienna',
#  'Wheat Beer - American Dark': 'Wheat Dark - American',
#  'Wheat Beer - American Pale': 'Wheat Pale - American',
#  'Wheat Beer - Dunkelweizen': 'Wheat Dunkelweizen',
#  'Wheat Beer - Hefeweizen': 'Wheat Beer Hefeweizen',
#  'Wheat Beer - Kristallweizen': 'Wheat Beer Kristallweizen',
#  'Wheat Beer - Wheatwine': 'Wheat Beer Wheatwine',
#  'Wheat Beer - Witbier': 'Wheat Beer Witbier',
#  'Wild Ale': 'Ale Wild',
#  'Wild/Sour Beers': 'Sour Wild',
#  'Winter Warmer': 'Winter Warmer'}

# %%
beers['style'].replace(style_dict, inplace=True)

# %%
beers.head()
# Out:
#        id                                  name  brewery_id state country  \
# 0  202522                        Olde Cogitator        2199    CA      US
# 1   82352  Konrads Stout Russian Imperial Stout       18604   NaN      NO
# 2  214879                        Scottish Right       44306    IN      US
# 3  320009               MegaMeow Imperial Stout        4378    WA      US
# 4  246438                       Peaches-N-Cream       44617    PA      US
#
#    style_renamed                      style availability   abv  \
# 0              0    Stout Oatmeal - English     Rotating   7.3
# 1              0     Stout Russian Imperial     Rotating  10.4
# 2              0             Ale - Scottish   Year-round   4.0
# 3              0  Stout Imperial - American       Winter   8.7
# 4              0       Ale Cream - American     Rotating   5.1
#
#                     notes retired
# 0  No notes at this time.       f
# 1  No notes at this time.       f
# 2  No notes at this time.       t
# 3    Every time this year       f
# 4  No notes at this time.       f

# %%
top_beer_info['Style'].replace(style_dict, inplace=True)

# %%
top_beer_info.head(5)
# Out:
#              Name  key  style_renamed    Style  Style Key  \
# 0           Amber  251              0  Altbier          8
# 1      Double Bag  252              0  Altbier          8
# 2  Long Trail Ale  253              0  Altbier          8
# 3    Doppelsticke  254              0  Altbier          8
# 4          Scurry  255              0  Altbier          8
#
#                           Brewery  \
# 0             Alaskan Brewing Co.
# 1          Long Trail Brewing Co.
# 2          Long Trail Brewing Co.
# 3  Uerige Obergärige Hausbrauerei
# 4               Off Color Brewing
#
#                                          Description  ABV  Ave Rating  \
# 0  Notes:Richly malty and long on the palate, wit...  5.3        3.65
# 1  Notes:This malty, full-bodied double alt is al...  7.2        3.90
# 2  Notes:Long Trail Ale is a full-bodied amber al...  5.0        3.58
# 3                                             Notes:  8.5        4.15
# 4  Notes:Just cause it's dark and German doesn't ...  5.3        3.67
#
#    Min IBU  ...  Body  Alcohol  Bitter  Sweet  Sour  Salty  Fruits  Hoppy  \
# 0       25  ...    32        9      47     74    33      0      33     57
# 1       25  ...    57       18      33     55    16      0      24     35
# 2       25  ...    37        6      42     43    11      0      10     54
# 3       25  ...    55       31      47    101    18      1      49     40
# 4       25  ...    69       10      63    120    14      0      19     36
#
#    Spices  Malty
# 0       8    111
# 1      12     84
# 2       4     62
# 3      16    119
# 4      15    218
#
# [5 rows x 22 columns]

# %%
top_beer_info.to_csv('top_beer_info_style_renamed.csv')

# %%
beers.to_csv('beers_style_renamed.csv')

# %%
top_beer_info = pd.read_csv(
        '/Users/ltexp1998/code/ltexp1998/zytholic_project/raw_data/top-beer-information/top_beer_information.csv')

beers = pd.read_csv(
        '/Users/ltexp1998/code/ltexp1998/zytholic_project/raw_data/Beers_Breweries_and_Beer Reviews/beers.csv'
    )

    # importation du fichier de corresponance des styles

style_xls = pd.read_excel(
        '/Users/ltexp1998/code/ltexp1998/zytholic_project/assets/style_convert.xlsx'
    )

style_xls.to_csv("/Users/ltexp1998/code/ltexp1998/zytholic_project/raw_data/style_rename.csv")

style_csv = pd.read_csv(
        '/Users/ltexp1998/code/ltexp1998/zytholic_project/raw_data/style_rename.csv'
    )

style_csv.drop(columns='Unnamed: 0', inplace=True)
style_csv.set_index('Dataset style', inplace=True)
style_csv.drop('Original', 0, inplace=True)
style_dict = style_csv.to_dict()
style_dict = style_dict['Unnamed: 1']

    # uniformaisation des styles sur les datasets

beers['style'].replace(style_dict, inplace=True)
top_beer_info['Style'].replace(style_dict, inplace=True)

    # exportation en csv des datasets modifiés

top_beer_info.to_csv('../raw_data/top_beer_info_style_renamed.csv')
beers.to_csv('../raw_data/beers_style_renamed.csv')
# Out:
# /var/folders/07/zjwdx2397n1gh6yj__wpmd980000gn/T/ipykernel_16712/3686733560.py:22: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   style_csv.drop('Original', 0, inplace=True)

# %%
import pandas as pd

PATH_CSV_BEERS = "https://drive.google.com/file/d/1YsXjInJiVoPFIOmPKoIV6EhwR_xlD_5t/view?usp=sharing"

PATH_CSV_TOP_BEER_INFO = "https://drive.google.com/file/d/1vQaSHO_au3h_Uqwa4r_p8rKvDNuB927i/view?usp=sharing"




top_beer_info = pd.read_csv(PATH_CSV_TOP_BEER_INFO)

beers = pd.read_csv(PATH_CSV_BEERS)

    # importation du fichier de corresponance des styles

style_xls = pd.read_excel(
            '/Users/ltexp1998/code/ltexp1998/zytholic_project/assets/style_convert.xlsx')

style_xls.to_csv("/Users/ltexp1998/code/ltexp1998/zytholic_project/raw_data/style_rename.csv")

style_csv = pd.read_csv(
            '/Users/ltexp1998/code/ltexp1998/zytholic_project/raw_data/style_rename.csv')

style_csv.drop(columns='Unnamed: 0', inplace=True)
style_csv.set_index('Dataset style', inplace=True)
style_csv.drop('Original', 0, inplace=True)

    # creation d'un dict pour replace de la correspondance

style_dict = style_csv.to_dict()
style_dict = style_dict['Unnamed: 1']

    # uniformaisation des styles sur les datasets

beers['style'].replace(style_dict, inplace=True)
top_beer_info['Style'].replace(style_dict, inplace=True)

    # exportation en csv des datasets modifiés

top_beer_info.to_csv('../raw_data/top_beer_info_style_renamed.csv')
beers.to_csv('../raw_data/beers_style_renamed.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /var/folders/07/zjwdx2397n1gh6yj__wpmd980000gn/T/ipykernel_16712/1696675330.py in <module>
#       8
#       9
# ---> 10 top_beer_info = pd.read_csv(PATH_CSV_TOP_BEER_INFO)
#      11
#      12 beers = pd.read_csv(PATH_CSV_BEERS)
#
# ~/.pyenv/versions/3.8.6/envs/zytholic_project/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.pyenv/versions/3.8.6/envs/zytholic_project/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.pyenv/versions/3.8.6/envs/zytholic_project/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~/.pyenv/versions/3.8.6/envs/zytholic_project/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~/.pyenv/versions/3.8.6/envs/zytholic_project/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~/.pyenv/versions/3.8.6/envs/zytholic_project/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~/.pyenv/versions/3.8.6/envs/zytholic_project/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~/.pyenv/versions/3.8.6/envs/zytholic_project/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/.pyenv/versions/3.8.6/envs/zytholic_project/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 6, saw 2
